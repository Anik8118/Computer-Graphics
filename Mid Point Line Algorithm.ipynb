# %%
import matplotlib.pyplot as plt

# %%
def Mid_Point(x1,y1):
  x_point = []
  y_point = []
  del_x = x2 - x1
  del_y = y2 - y1
  del_D = 2*(del_y - del_x)
  D_not = 2*del_y - del_x
  for _ in range(del_x if del_x >= del_y else del_y):
    if D_not >= 0:
      x1+=1
      y1+=1
      D_not+=del_D
      x_point.append(x1)
      y_point.append(y1)
    else:
      x1+=1
      D_not+= 2*del_y
      x_point.append(x1)
      y_point.append(y1)
  result = zip(x_point, y_point)
  for _ in result:
    print(_, end=" ")
  plt.scatter(x_point, y_point)
  plt.xlabel("X-Axis")
  plt.ylabel("Y-Axis")
  plt.title("Mid Point Line Algorithm")

# %%
x1 = int(input())
x2 = int(input())
y1 = int(input())
y2 = int(input())
Mid_Point(x1, y1)
# Out:
# 20
# 30
# 10
# 18
# (21, 11) (22, 12) (23, 12) (24, 13) (25, 14) (26, 15) (27, 16) (28, 16) (29, 17) (30, 18)
